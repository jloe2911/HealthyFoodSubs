# %% [markdown]
# **------------------------------------------------------------------------------------------------------------------------------------------------------**
#
# k-fold cross-validation
#
# **Input: Knowledge Graph**
#
# **GNN-based Link Prediction Model: GCN, GraphSAGE, and GAT**
#
# **Output: "Food" Embeddings**
#
# **------------------------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# # Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import os
import re
import random
import itertools
import warnings
warnings.simplefilter("ignore")

import torch_geometric
from torch_geometric.data import HeteroData
import torch_geometric.transforms as T
from torch_geometric.nn import GCNConv, SAGEConv, GATConv, Linear, to_hetero

import torch
import torch.nn as nn
from torch.nn import Linear
import torch.nn.functional as F

# %%
#vModel = 'GCN'
vModel = 'GraphSAGE'
#vModel = 'GAT'

# %%
k_fold = 10
n_input_feat = 10
n_epochs = 201

# %% [markdown]
# # 1) Create HeteroGraph

# %%
def load_node_csv(path, index_col, encoders=None, **kwargs):
    df = pd.read_csv(path, index_col=index_col, **kwargs)
    mapping = {index: i for i, index in enumerate(df.index.unique())}

    x = None
    if encoders is not None:
        xs = [encoder(df[col]) for col, encoder in encoders.items()]
        x = torch.cat(xs, dim=-1)

    return x, mapping

# %%
def load_edge_csv(path, src_index_col, src_mapping, dst_index_col, dst_mapping, encoders=None, **kwargs):
    df = pd.read_csv(path, **kwargs)

    src = [src_mapping[index] for index in df[src_index_col]]
    dst = [dst_mapping[index] for index in df[dst_index_col]]
    edge_index = torch.tensor([src, dst])

    edge_attr = None
    if encoders is not None:
        edge_attrs = [encoder(df[col]) for col, encoder in encoders.items()]
        edge_attr = torch.cat(edge_attrs, dim=-1)

    return edge_index, edge_attr

# %%
_, food_mapping = load_node_csv('../Input Data/data/all_foods.csv', index_col='subject')
_, nutrient_mapping = load_node_csv('../Input Data/data/df_food_nutrient.csv', index_col='object')
_, tag_mapping = load_node_csv('../Input Data/data/df_food_tag.csv', index_col='object')
_, category_mapping = load_node_csv('../Input Data/data/df_food_cat.csv', index_col='object')
_, flavor_mapping = load_node_csv('../Input Data/data/df_food_flavor.csv', index_col='object')
_, product_mapping = load_node_csv('../Input Data/data/df_product_ingredient.csv', index_col='subject')
_, ingredient_mapping = load_node_csv('../Input Data/data/df_product_ingredient.csv', index_col='object')

# %%
food_subs_index, _ = load_edge_csv('../Input Data/data/df_food_subs.csv', src_index_col='source_id', src_mapping=food_mapping, dst_index_col='destination_id', dst_mapping=food_mapping)
subs_food_index, _ = load_edge_csv('../Input Data/data/df_food_subs.csv', src_index_col='destination_id', src_mapping=food_mapping, dst_index_col='source_id', dst_mapping=food_mapping)
food_nutrient_index, _ = load_edge_csv('../Input Data/data/df_food_nutrient.csv', src_index_col='subject', src_mapping=food_mapping, dst_index_col='object', dst_mapping=nutrient_mapping)
food_tag_index, _ = load_edge_csv('../Input Data/data/df_food_tag.csv', src_index_col='subject', src_mapping=food_mapping, dst_index_col='object', dst_mapping=tag_mapping)
food_cat_index, _ = load_edge_csv('../Input Data/data/df_food_cat.csv', src_index_col='subject', src_mapping=food_mapping, dst_index_col='object', dst_mapping=category_mapping)
food_flavor_index, _ = load_edge_csv('../Input Data/data/df_food_flavor.csv', src_index_col='subject', src_mapping=food_mapping, dst_index_col='object', dst_mapping=flavor_mapping)
product_ingredient_index, _ = load_edge_csv('../Input Data/data/df_product_ingredient.csv', src_index_col='subject', src_mapping=product_mapping, dst_index_col='object', dst_mapping=ingredient_mapping)
food_ingredient_index, _ = load_edge_csv('../Input Data/data/df_food_ingredient.csv', src_index_col='subject', src_mapping=food_mapping, dst_index_col='object', dst_mapping=ingredient_mapping)
ingredient_food_index, _ = load_edge_csv('../Input Data/data/df_food_ingredient.csv', src_index_col='object', src_mapping=ingredient_mapping, dst_index_col='subject', dst_mapping=food_mapping)

# %%
data = HeteroData()

data['Food'].num_nodes = len(food_mapping)
data['Nutrient'].num_nodes = len(nutrient_mapping)
data['Tag'].num_nodes = len(tag_mapping)
data['Category'].num_nodes = len(category_mapping)
data['Flavor'].num_nodes = len(flavor_mapping)
#data['Product'].num_nodes = len(product_mapping)
#data['Ingredient'].num_nodes = len(ingredient_mapping)

data['Food', 'isSubstitutedBy', 'Food'].edge_index = food_subs_index
data['Food', 'substitutes', 'Food'].edge_index = subs_food_index
data['Food', 'containsNutrient', 'Nutrient'].edge_index = food_nutrient_index
data['Food', 'hasTag', 'Tag'].edge_index = food_tag_index
data['Food', 'isInCategory', 'Category'].edge_index = food_cat_index
data['Food', 'hasFlavor', 'Flavor'].edge_index = food_flavor_index
#data['Product', 'containsIngredient', 'Ingredient'] = product_ingredient_index
#data['Food', 'sameAs', 'Ingredient'].edge_index = food_ingredient_index
#data['Ingredient', 'sameAs', 'Food'].edge_index = ingredient_food_index

# %%
data
# Out:
# HeteroData(
#   Food={ num_nodes=9372 },
#   Nutrient={ num_nodes=63883 },
#   Tag={ num_nodes=25 },
#   Category={ num_nodes=13 },
#   Flavor={ num_nodes=272 },
#   (Food, isSubstitutedBy, Food)={ edge_index=[2, 1841] },
#   (Food, substitutes, Food)={ edge_index=[2, 1841] },
#   (Food, containsNutrient, Nutrient)={ edge_index=[2, 300523] },
#   (Food, hasTag, Tag)={ edge_index=[2, 17746] },
#   (Food, isInCategory, Category)={ edge_index=[2, 1667] },
#   (Food, hasFlavor, Flavor)={ edge_index=[2, 11167] }
# )

# %% [markdown]
# # 2) Run Model

# %% [markdown]
# **GCN**

# %%
class GCNEncoder(torch.nn.Module):
    def __init__(self, hidden_channels, out_channels):
        super().__init__()
        self.conv1 = GCNConv(-1, hidden_channels)
        self.conv2 = GCNConv(-1, out_channels)

    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index).relu()
        x = self.conv2(x, edge_index)
        return x

# %% [markdown]
# **GraphSAGE**

# %%
class GraphSAGEEncoder(torch.nn.Module):
    def __init__(self, hidden_channels, out_channels):
        super().__init__()
        self.conv1 = SAGEConv((-1, -1), hidden_channels)
        self.conv2 = SAGEConv((-1, -1), out_channels)

    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index).relu()
        x = self.conv2(x, edge_index)
        return x

# %% [markdown]
# **GAT**

# %%
class GATEncoder(torch.nn.Module):
    def __init__(self, hidden_channels, out_channels):
        super().__init__()
        self.conv1 = GATConv((-1, -1), hidden_channels, add_self_loops=False)
        self.lin1 = Linear(n_input_feat, hidden_channels)
        self.conv2 = GATConv((-1, -1), out_channels, add_self_loops=False)
        self.lin2 = Linear(hidden_channels, out_channels)

    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index) + self.lin1(x)
        x = x.relu()
        x = self.conv2(x, edge_index) + self.lin2(x)
        return x

# %% [markdown]
# **------------------------------------------------------------------------------------------------------------------------------------------------------**

# %%
class Model(torch.nn.Module):
    def __init__(self, hidden_channels):
        super().__init__()
        if vModel == 'GCN':
            self.encoder = GCNEncoder(hidden_channels, hidden_channels)
        elif vModel == 'GraphSAGE':
            self.encoder = GraphSAGEEncoder(hidden_channels, hidden_channels)
        elif vModel == 'GAT': 
            self.encoder = GATEncoder(hidden_channels, hidden_channels)
        else:
            'No Model is chosen !'
        self.encoder = to_hetero(self.encoder, data.metadata(), aggr='sum')
        self.decoder = EdgeDecoder(hidden_channels)

    def forward(self, x_dict, edge_index_dict, edge_label_index):
        z_dict = self.encoder(x_dict, edge_index_dict)
        return z_dict, self.decoder(z_dict, edge_label_index)

# %%
class EdgeDecoder(torch.nn.Module):
    def __init__(self, hidden_channels):
        super().__init__()
        self.lin1 = Linear(2 * hidden_channels, hidden_channels)
        self.lin2 = Linear(hidden_channels, 1)

    def forward(self, z_dict, edge_label_index):
        row, col = edge_label_index
        z = torch.cat([z_dict['Food'][row], z_dict['Food'][col]], dim=-1)
        z = self.lin1(z).relu()
        z = self.lin2(z)
        return z.view(-1)

# %%
def mse_loss(pred, target):
    return (pred - target.to(pred.dtype)).pow(2).mean()

# %% [markdown]
# **------------------------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# **Add random Node Features**

# %%
node_types, edge_types = data.metadata()
for node in node_types: 
    data[node].x = torch.rand(data[node].num_nodes, n_input_feat)

# %% [markdown]
# **------------------------------------------------------------------------------------------------------------------------------------------------------**

# %%
def train(data):    
    print('------------------------------------------------------------------')
    for epoch in range(n_epochs):

        #forward
        h, pred = model(data.x_dict, data.edge_index_dict, data['Food', 'isSubstitutedBy', 'Food'].edge_index)
        target = data['Food', 'isSubstitutedBy', 'Food'].edge_label

        #loss
        loss = mse_loss(pred, target)

        #backward
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        _, _, train_rmse = eval_model(data)
        
        if epoch % 10 == 0:
            print(f'Epoch: {epoch:03d}, Loss: {loss:.4f}, Train: {train_rmse:.4f}')

# %%
@torch.no_grad()
def eval_model(data):
    model.eval()
    h, pred = model(data.x_dict, data.edge_index_dict, data['Food', 'isSubstitutedBy', 'Food'].edge_index)
    pred = pred.clamp(min=0, max=1)
    target = data['Food', 'isSubstitutedBy', 'Food'].edge_label.float()
    rmse = F.mse_loss(pred, target).sqrt()
    return h, pred, float(rmse)

# %%
def get_test_foods(data, i):
    test_u = data['Food', 'isSubstitutedBy', 'Food']['edge_label_index'][0]

    reverse_food_mapping = dict(zip(food_mapping.values(),food_mapping.keys()))
    reverse_test_u = []

    for u in test_u:
        reverse_test_u.append(reverse_food_mapping[u.item()])

    foods_2_test = pd.DataFrame()
    foods_2_test['id'] = reverse_test_u
    foods_2_test.to_csv(f'../Output/k_fold/{vModel}_{i}_foods_2_test.csv')

# %%
for i in range(k_fold):    
    
    #Split into Train, Test, Val Sets
    train_data, val_data, test_data = T.RandomLinkSplit(
        num_val=0.1,
        num_test=0.1,
        neg_sampling_ratio=0,
        edge_types=[('Food', 'isSubstitutedBy', 'Food')],
        rev_edge_types=[('Food', 'substitutes', 'Food')],
    )(data)

    #Initialize Model
    model = Model(hidden_channels=32)

    with torch.no_grad():
        model.encoder(train_data.x_dict, train_data.edge_index_dict)

    optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

    train_data['Food', 'isSubstitutedBy', 'Food'].edge_label = torch.ones(train_data['Food', 'isSubstitutedBy', 'Food'].num_edges)
    test_data['Food', 'isSubstitutedBy', 'Food'].edge_label = torch.ones(test_data['Food', 'isSubstitutedBy', 'Food'].num_edges)
    val_data['Food', 'isSubstitutedBy', 'Food'].edge_label = torch.ones(val_data['Food', 'isSubstitutedBy', 'Food'].num_edges)
    
    #Train Model
    train(train_data)

    #Remember the Foods that are contained in the Test Set
    get_test_foods(test_data, i)
    
    #Get Embeddings from the Test Foods
    with torch.no_grad():
        h, pred, rmse = eval_model(test_data)

    foods = food_mapping.keys()
    food_embeddings = dict(zip(foods, h['Food']))

    for j in range(2):
        fw = open(f'../Output/k_fold/{vModel}_{i}_food_embeddings.txt','w')
        fw.write(str(len(foods))+' '+str(len(h['Food'][0]))+'\n')
        for food in foods:
            fw.write(food+' ')
            for i in range(len(h['Food'][0])):
                value = str(food_embeddings[food][i].item()).strip()
                fw.write(value+' ')
            fw.write('\n')
# Out:
# ------------------------------------------------------------------
# Epoch: 000, Loss: 0.8723, Train: 0.6578
# Epoch: 010, Loss: 0.0173, Train: 0.0244
# Epoch: 020, Loss: 0.0112, Train: 0.0547
# Epoch: 030, Loss: 0.0155, Train: 0.0930
# Epoch: 040, Loss: 0.0068, Train: 0.0713
# Epoch: 050, Loss: 0.0044, Train: 0.0630
# Epoch: 060, Loss: 0.0029, Train: 0.0491
# Epoch: 070, Loss: 0.0025, Train: 0.0421
# Epoch: 080, Loss: 0.0022, Train: 0.0379
# Epoch: 090, Loss: 0.0019, Train: 0.0351
# Epoch: 100, Loss: 0.0017, Train: 0.0324
# Epoch: 110, Loss: 0.0015, Train: 0.0295
# Epoch: 120, Loss: 0.0013, Train: 0.0268
# Epoch: 130, Loss: 0.0012, Train: 0.0258
# Epoch: 140, Loss: 0.0010, Train: 0.0244
# Epoch: 150, Loss: 0.0009, Train: 0.0230
# Epoch: 160, Loss: 0.0008, Train: 0.0220
# Epoch: 170, Loss: 0.0008, Train: 0.0209
# Epoch: 180, Loss: 0.0007, Train: 0.0200
# Epoch: 190, Loss: 0.0006, Train: 0.0191
# Epoch: 200, Loss: 0.0006, Train: 0.0183
# ------------------------------------------------------------------
# Epoch: 000, Loss: 1.6669, Train: 0.7899
# Epoch: 010, Loss: 0.0280, Train: 0.0399
# Epoch: 020, Loss: 0.0558, Train: 0.1911
# Epoch: 030, Loss: 0.0124, Train: 0.1220
# Epoch: 040, Loss: 0.0061, Train: 0.0497
# Epoch: 050, Loss: 0.0056, Train: 0.0336
# Epoch: 060, Loss: 0.0038, Train: 0.0384
# Epoch: 070, Loss: 0.0035, Train: 0.0432
# Epoch: 080, Loss: 0.0031, Train: 0.0432
# Epoch: 090, Loss: 0.0028, Train: 0.0406
# Epoch: 100, Loss: 0.0024, Train: 0.0367
# Epoch: 110, Loss: 0.0021, Train: 0.0325
# Epoch: 120, Loss: 0.0019, Train: 0.0322
# Epoch: 130, Loss: 0.0017, Train: 0.0295
# Epoch: 140, Loss: 0.0015, Train: 0.0277
# Epoch: 150, Loss: 0.0014, Train: 0.0265
# Epoch: 160, Loss: 0.0013, Train: 0.0249
# Epoch: 170, Loss: 0.0012, Train: 0.0237
# Epoch: 180, Loss: 0.0011, Train: 0.0227
# Epoch: 190, Loss: 0.0010, Train: 0.0215
# Epoch: 200, Loss: 0.0009, Train: 0.0202
# ------------------------------------------------------------------
# Epoch: 000, Loss: 1.7288, Train: 0.4804
# Epoch: 010, Loss: 0.1339, Train: 0.0109
# Epoch: 020, Loss: 0.0344, Train: 0.0094
# Epoch: 030, Loss: 0.0078, Train: 0.0188
# Epoch: 040, Loss: 0.0045, Train: 0.0292
# Epoch: 050, Loss: 0.0040, Train: 0.0352
# Epoch: 060, Loss: 0.0036, Train: 0.0352
# Epoch: 070, Loss: 0.0032, Train: 0.0344
# Epoch: 080, Loss: 0.0029, Train: 0.0349
# Epoch: 090, Loss: 0.0026, Train: 0.0363
# Epoch: 100, Loss: 0.0024, Train: 0.0366
# Epoch: 110, Loss: 0.0022, Train: 0.0345
# Epoch: 120, Loss: 0.0020, Train: 0.0319
# Epoch: 130, Loss: 0.0018, Train: 0.0307
# Epoch: 140, Loss: 0.0017, Train: 0.0298
# Epoch: 150, Loss: 0.0016, Train: 0.0283
# Epoch: 160, Loss: 0.0015, Train: 0.0271
# Epoch: 170, Loss: 0.0013, Train: 0.0261
# Epoch: 180, Loss: 0.0012, Train: 0.0249
# Epoch: 190, Loss: 0.0012, Train: 0.0240
# Epoch: 200, Loss: 0.0011, Train: 0.0229
# ------------------------------------------------------------------
# Epoch: 000, Loss: 1.1434, Train: 0.5284
# Epoch: 010, Loss: 0.0081, Train: 0.1500
# Epoch: 020, Loss: 0.0195, Train: 0.1213
# Epoch: 030, Loss: 0.0052, Train: 0.0307
# Epoch: 040, Loss: 0.0049, Train: 0.0455
# Epoch: 050, Loss: 0.0037, Train: 0.0535
# Epoch: 060, Loss: 0.0029, Train: 0.0345
# Epoch: 070, Loss: 0.0024, Train: 0.0381
# Epoch: 080, Loss: 0.0020, Train: 0.0311
# Epoch: 090, Loss: 0.0017, Train: 0.0308
# Epoch: 100, Loss: 0.0014, Train: 0.0263
# Epoch: 110, Loss: 0.0011, Train: 0.0235
# Epoch: 120, Loss: 0.0009, Train: 0.0216
# Epoch: 130, Loss: 0.0008, Train: 0.0198
# Epoch: 140, Loss: 0.0007, Train: 0.0182
# Epoch: 150, Loss: 0.0006, Train: 0.0168
# Epoch: 160, Loss: 0.0005, Train: 0.0158
# Epoch: 170, Loss: 0.0005, Train: 0.0148
# Epoch: 180, Loss: 0.0004, Train: 0.0139
# Epoch: 190, Loss: 0.0004, Train: 0.0131
# Epoch: 200, Loss: 0.0003, Train: 0.0124
# ------------------------------------------------------------------
# Epoch: 000, Loss: 1.3145, Train: 0.4625
# Epoch: 010, Loss: 0.0065, Train: 0.1478
# Epoch: 020, Loss: 0.0058, Train: 0.1141
# Epoch: 030, Loss: 0.0039, Train: 0.0747
# Epoch: 040, Loss: 0.0032, Train: 0.0557
# Epoch: 050, Loss: 0.0025, Train: 0.0453
# Epoch: 060, Loss: 0.0021, Train: 0.0407
# Epoch: 070, Loss: 0.0019, Train: 0.0368
# Epoch: 080, Loss: 0.0016, Train: 0.0314
# Epoch: 090, Loss: 0.0014, Train: 0.0272
# Epoch: 100, Loss: 0.0013, Train: 0.0260
# Epoch: 110, Loss: 0.0012, Train: 0.0257
# Epoch: 120, Loss: 0.0011, Train: 0.0241
# Epoch: 130, Loss: 0.0010, Train: 0.0226
# Epoch: 140, Loss: 0.0009, Train: 0.0219
# Epoch: 150, Loss: 0.0008, Train: 0.0207
# Epoch: 160, Loss: 0.0007, Train: 0.0199
# Epoch: 170, Loss: 0.0007, Train: 0.0190
# Epoch: 180, Loss: 0.0006, Train: 0.0183
# Epoch: 190, Loss: 0.0006, Train: 0.0175
# Epoch: 200, Loss: 0.0005, Train: 0.0169
# ------------------------------------------------------------------
# Epoch: 000, Loss: 1.4983, Train: 0.4617
# Epoch: 010, Loss: 0.0753, Train: 0.0360
# Epoch: 020, Loss: 0.0407, Train: 0.0144
# Epoch: 030, Loss: 0.0081, Train: 0.0149
# Epoch: 040, Loss: 0.0027, Train: 0.0223
# Epoch: 050, Loss: 0.0024, Train: 0.0283
# Epoch: 060, Loss: 0.0020, Train: 0.0284
# Epoch: 070, Loss: 0.0016, Train: 0.0264
# Epoch: 080, Loss: 0.0014, Train: 0.0247
# Epoch: 090, Loss: 0.0013, Train: 0.0239
# Epoch: 100, Loss: 0.0011, Train: 0.0239
# Epoch: 110, Loss: 0.0010, Train: 0.0238
# Epoch: 120, Loss: 0.0009, Train: 0.0230
# Epoch: 130, Loss: 0.0008, Train: 0.0214
# Epoch: 140, Loss: 0.0008, Train: 0.0202
# Epoch: 150, Loss: 0.0007, Train: 0.0195
# Epoch: 160, Loss: 0.0006, Train: 0.0187
# Epoch: 170, Loss: 0.0006, Train: 0.0178
# Epoch: 180, Loss: 0.0005, Train: 0.0171
# Epoch: 190, Loss: 0.0005, Train: 0.0164
# Epoch: 200, Loss: 0.0005, Train: 0.0158
# ------------------------------------------------------------------
# Epoch: 000, Loss: 1.1624, Train: 0.5440
# Epoch: 010, Loss: 0.0084, Train: 0.1212
# Epoch: 020, Loss: 0.0067, Train: 0.1137
# Epoch: 030, Loss: 0.0046, Train: 0.0802
# Epoch: 040, Loss: 0.0031, Train: 0.0579
# Epoch: 050, Loss: 0.0022, Train: 0.0420
# Epoch: 060, Loss: 0.0015, Train: 0.0294
# Epoch: 070, Loss: 0.0011, Train: 0.0217
# Epoch: 080, Loss: 0.0010, Train: 0.0200
# Epoch: 090, Loss: 0.0008, Train: 0.0212
# Epoch: 100, Loss: 0.0007, Train: 0.0197
# Epoch: 110, Loss: 0.0006, Train: 0.0170
# Epoch: 120, Loss: 0.0005, Train: 0.0164
# Epoch: 130, Loss: 0.0004, Train: 0.0151
# Epoch: 140, Loss: 0.0004, Train: 0.0139
# Epoch: 150, Loss: 0.0003, Train: 0.0130
# Epoch: 160, Loss: 0.0003, Train: 0.0120
# Epoch: 170, Loss: 0.0002, Train: 0.0112
# Epoch: 180, Loss: 0.0002, Train: 0.0105
# Epoch: 190, Loss: 0.0002, Train: 0.0098
# Epoch: 200, Loss: 0.0002, Train: 0.0092
# ------------------------------------------------------------------
# Epoch: 000, Loss: 0.7927, Train: 0.1069
# Epoch: 010, Loss: 0.0306, Train: 0.0082
# Epoch: 020, Loss: 0.0190, Train: 0.0685
# Epoch: 030, Loss: 0.0201, Train: 0.1360
# Epoch: 040, Loss: 0.0044, Train: 0.0675
# Epoch: 050, Loss: 0.0058, Train: 0.0323
# Epoch: 060, Loss: 0.0036, Train: 0.0329
# Epoch: 070, Loss: 0.0030, Train: 0.0394
# Epoch: 080, Loss: 0.0028, Train: 0.0414
# Epoch: 090, Loss: 0.0025, Train: 0.0398
# Epoch: 100, Loss: 0.0022, Train: 0.0372
# Epoch: 110, Loss: 0.0020, Train: 0.0348
# Epoch: 120, Loss: 0.0018, Train: 0.0328
# Epoch: 130, Loss: 0.0017, Train: 0.0312
# Epoch: 140, Loss: 0.0016, Train: 0.0298
# Epoch: 150, Loss: 0.0015, Train: 0.0286
# Epoch: 160, Loss: 0.0013, Train: 0.0274
# Epoch: 170, Loss: 0.0013, Train: 0.0263
# Epoch: 180, Loss: 0.0012, Train: 0.0252
# Epoch: 190, Loss: 0.0011, Train: 0.0242
# Epoch: 200, Loss: 0.0010, Train: 0.0233
# ------------------------------------------------------------------
# Epoch: 000, Loss: 1.1030, Train: 0.0948
# Epoch: 010, Loss: 0.0887, Train: 0.0411
# Epoch: 020, Loss: 0.0439, Train: 0.0132
# Epoch: 030, Loss: 0.0101, Train: 0.0232
# Epoch: 040, Loss: 0.0050, Train: 0.0407
# Epoch: 050, Loss: 0.0042, Train: 0.0459
# Epoch: 060, Loss: 0.0033, Train: 0.0430
# Epoch: 070, Loss: 0.0027, Train: 0.0382
# Epoch: 080, Loss: 0.0022, Train: 0.0342
# Epoch: 090, Loss: 0.0020, Train: 0.0316
# Epoch: 100, Loss: 0.0017, Train: 0.0304
# Epoch: 110, Loss: 0.0015, Train: 0.0299
# Epoch: 120, Loss: 0.0014, Train: 0.0287
# Epoch: 130, Loss: 0.0012, Train: 0.0267
# Epoch: 140, Loss: 0.0011, Train: 0.0250
# Epoch: 150, Loss: 0.0010, Train: 0.0239
# Epoch: 160, Loss: 0.0009, Train: 0.0228
# Epoch: 170, Loss: 0.0008, Train: 0.0216
# Epoch: 180, Loss: 0.0008, Train: 0.0207
# Epoch: 190, Loss: 0.0007, Train: 0.0199
# Epoch: 200, Loss: 0.0007, Train: 0.0190
# ------------------------------------------------------------------
# Epoch: 000, Loss: 0.9658, Train: 0.1482
# Epoch: 010, Loss: 0.1699, Train: 0.0169
# Epoch: 020, Loss: 0.0318, Train: 0.0126
# Epoch: 030, Loss: 0.0063, Train: 0.0276
# Epoch: 040, Loss: 0.0051, Train: 0.0442
# Epoch: 050, Loss: 0.0045, Train: 0.0493
# Epoch: 060, Loss: 0.0035, Train: 0.0452
# Epoch: 070, Loss: 0.0028, Train: 0.0394
# Epoch: 080, Loss: 0.0023, Train: 0.0345
# Epoch: 090, Loss: 0.0021, Train: 0.0312
# Epoch: 100, Loss: 0.0019, Train: 0.0298
# Epoch: 110, Loss: 0.0017, Train: 0.0296
# Epoch: 120, Loss: 0.0016, Train: 0.0291
# Epoch: 130, Loss: 0.0014, Train: 0.0274
# Epoch: 140, Loss: 0.0013, Train: 0.0258
# Epoch: 150, Loss: 0.0012, Train: 0.0248
# Epoch: 160, Loss: 0.0011, Train: 0.0237
# Epoch: 170, Loss: 0.0010, Train: 0.0226
# Epoch: 180, Loss: 0.0009, Train: 0.0218
# Epoch: 190, Loss: 0.0009, Train: 0.0208
# Epoch: 200, Loss: 0.0008, Train: 0.0200
